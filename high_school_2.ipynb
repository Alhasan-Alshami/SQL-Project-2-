# %% [markdown]
# # (SQL, Jupyter Notebook) Project (2)

# %% [markdown]
# ### By using high_school From "(SQL, Jupyter Notebook) Project (1)", We created a copied version and named it high_school_2
#
# ### Requirements:
#
# 1. Creating a table "Outstanding_Students" where the cumulative average higher than 90
# 2. Creating a table "Failed_Students" where the cumulative average less than 60
# 3. Displaying student names that start with letter "A" (LIKE Function)
# 4. Applying AVG, MAX and MIN (Aggregate functions) to the Students_GPA and add a clear label to the result
# 5. Display the names of outstanding students in sixth-level with a perfect cumulative average of 100
# 6. Display first-level students aged between 15 and 16
# 7. Display the number of students in Level 2
# 8. Review students paths in school without repetition
# 9. Display material names in capital letters
# 10. Display the rounded average cumulative GPA using numeric functions
# 11. Update rows in Students_gender: change F to Female and M to Male using (string functions)
# 12. In a new table, update cumulative GPA with less than 60 by increasing it by 5 grades
#
# ---

# %% [markdown]
# #### Creating a table "Outstanding_Students" where the cumulative average higher than 90

# %%
CREATE TABLE
    Outstanding_Students
SELECT
    *
FROM
    students_2
WHERE
    Students_GPA > 90
ORDER BY
    Students_GPA ASC;

# %% [markdown]
# ![01-Outstanding_students.png](attachment:01-Outstanding_students.png)
#
# ---

# %% [markdown]
# #### Creating a table "Failed_Students" from "Students_2" where the cumulative average less than 60

# %%
CREATE TABLE
    Failed_Students AS
SELECT
    *
FROM
    students_2
WHERE
    Students_GPA < 60
ORDER BY
    Students_GPA ASC;

# %% [markdown]
# ![02-failed_students.png](attachment:02-failed_students.png)
#
# ---

# %% [markdown]
# #### Displaying student names that start with letter "A" (LIKE Function)

# %%
SELECT
    *
FROM
    students_2
WHERE
    Students_name LIKE 'A%';

# %% [markdown]
# #### Applying AVG, MAX and MIN (Aggregate functions) to the Students_GPA and add a clear label to the result

# %%
SELECT
    AVG(Students_GPA) AS AVG_GPA,
    MAX(Students_GPA) AS MAX_GPA,
    MIN(Students_GPA) AS MIN_GPA
FROM
    students_2;

# %% [markdown]
# #### Display the names of outstanding students in sixth-level with a perfect cumulative average of 100

# %%
SELECT
    *
FROM
    students_2
WHERE
    Academic_level = 6
    AND Students_GPA = 100;

# %% [markdown]
# #### Display first-level students aged between 15 and 16

# %%
SELECT
    *
FROM
    students_2
WHERE
    academic_level = 1
    AND Birth_day >= '2008-01-01';

# %% [markdown]
# #### Display the number of students in Level 2

# %%
SELECT
    COUNT(*)
FROM
    students_2
WHERE
    Academic_level = 2;

# %% [markdown]
# #### Review students paths in school without repetition

# %%
SELECT DISTINCT
    Track
FROM
    students_2;

# %% [markdown]
# #### Display material names in capital letters

# %%
SELECT
    UPPER(Material_name)
FROM
    materials_2;

# %% [markdown]
# #### Display the rounded average cumulative GPA using numeric functions

# %%
SELECT
    ROUND(AVG(Students_GPA), 0)
FROM
    students_2;

# %% [markdown]
# #### Update rows in Students_gender: change F to Female and M to Male using (string functions)

# %%
-- Update 'F' to 'Female'
UPDATE students_2
SET
    Students_gender = CONCAT ('Fe', 'male')
WHERE
    Students_gender = 'F';

-- Update 'M' to 'Male'
UPDATE students_2
SET
    Students_gender = CONCAT ('Ma', 'le')
WHERE
    Students_gender = 'M';

# %% [markdown]
# #### In a new table, update cumulative GPA with less than 60 by increasing it by 5 grades

# %%
CREATE TABLE
    Updated_GPA
SELECT
    Students_id,
    Students_GPA + 5 AS Updated_GPA
FROM
    students_2
WHERE
    Students_GPA < 60;

# %% [markdown]
# ![03-Updated_GPA.png](attachment:03-Updated_GPA.png)
#
# ---

# %% [markdown]
# #### New Tables
#
# ![04-New Tables.png](<attachment:04-New Tables.png>)

# %% [markdown]
# ---
